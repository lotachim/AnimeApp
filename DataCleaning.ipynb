# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Lotachim/Downloads/archive (3)/Top_Anime_data.csv')

# %%
df
# Out:
#      Score  Popularity  Rank  Members  \
# 0     9.38         284     1      710
# 1     9.09           3     2        3
# 2     9.07          13     3        2
# 3     9.06         342     4      630
# 4     9.05          21     5        2
# ..     ...         ...   ...      ...
# 995   7.80        4003   996       31
# 996   7.80        1658   997      136
# 997   7.80        3114   998       50
# 998   7.80        3194   999       47
# 999   7.80        3598  1000       38
#
#                                            Description  \
# 0    During their decade-long quest to defeat the D...
# 1    After a horrific alchemy experiment goes wrong...
# 2    Eccentric scientist Rintarou Okabe has a never...
# 3    Gintoki, Shinpachi, and Kagura return as the f...
# 4    Seeking to restore humanity's diminishing hope...
# ..                                                 ...
# 995  Half retelling of the original Frontier series...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Score        1000 non-null   float64
#  1   Popularity   1000 non-null   int64
#  2   Rank         1000 non-null   int64
#  3   Members      1000 non-null   int64
#  4   Description  1000 non-null   object
#  5   Synonyms     709 non-null    object
#  6   Japanese     999 non-null    object
#  7   English      859 non-null    object
#  8   Type         1000 non-null   object
#  9   Episodes     1000 non-null   object
#  10  Status       1000 non-null   object
#  11  Aired        1000 non-null   object
#  12  Premiered    569 non-null    object
#  13  Broadcast    569 non-null    object
#  14  Producers    1000 non-null   object
#  15  Licensors    1000 non-null   object
#  16  Studios      1000 non-null   object
#  17  Source       1000 non-null   object
# ...

# %%
total_missing = df.isnull().sum().sum()

print("Total number of missing values in the dataset:", total_missing)
# Out:
# Total number of missing values in the dataset: 2003

# %%
df = df.dropna()

# %%
df
# Out:
#      Score  Popularity  Rank  Members  \
# 0     9.38         284     1      710
# 1     9.09           3     2        3
# 3     9.06         342     4      630
# 6     9.04           9     7        2
# 7     9.03         393     8      555
# ..     ...         ...   ...      ...
# 954   7.82        1266   955      189
# 964   7.82         565   965      403
# 974   7.81          92   975        1
# 975   7.81         250   976      769
# 981   7.81        1165   982      207
#
#                                            Description  \
# 0    During their decade-long quest to defeat the D...
# 1    After a horrific alchemy experiment goes wrong...
# 3    Gintoki, Shinpachi, and Kagura return as the f...
# 6    Hunters devote themselves to accomplishing haz...
# 7    After a one-year hiatus, Shinpachi Shimura ret...
# ..                                                 ...
# 954  Following their heroic efforts at Walter Park,...
# ...

# %%
df.head(20)
# Out:
#     Score  Popularity  Rank  Members  \
# 0    9.38         284     1      710
# 1    9.09           3     2        3
# 3    9.06         342     4      630
# 6    9.04           9     7        2
# 7    9.03         393     8      555
# 8    9.02         411     9      538
# 10   9.02         738    11      325
# 11   9.01         178    12      926
# 12   8.98         473    13      477
# 13   8.98         761    14      314
# 14   8.94         140    15        1
# 22   8.89        1399    23      168
# 23   8.88        1213    24      198
# 27   8.84         184    28      916
# 34   8.79          35    35        1
# 41   8.76         102    42        1
# 48   8.74        3051    49       52
# 49   8.73         908    50      266
# 50   8.72          19    51        2
# 56   8.69         907    57      267
#
#                                           Description  \
# 0   During their decade-long quest to defeat the D...
# 1   After a horrific alchemy experiment goes wrong...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162 entries, 0 to 981
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Score        162 non-null    float64
#  1   Popularity   162 non-null    int64
#  2   Rank         162 non-null    int64
#  3   Members      162 non-null    int64
#  4   Description  162 non-null    object
#  5   Synonyms     162 non-null    object
#  6   Japanese     162 non-null    object
#  7   English      162 non-null    object
#  8   Type         162 non-null    object
#  9   Episodes     162 non-null    object
#  10  Status       162 non-null    object
#  11  Aired        162 non-null    object
#  12  Premiered    162 non-null    object
#  13  Broadcast    162 non-null    object
#  14  Producers    162 non-null    object
#  15  Licensors    162 non-null    object
#  16  Studios      162 non-null    object
#  17  Source       162 non-null    object
# ...

# %%
df = df[['English','Score' ,'Rating', 'Genres', 'Studios' , 'Source']]

# %%
df
# Out:
#                                                English  Score  \
# 0                        Frieren: Beyond Journey's End   9.38
# 1                     Fullmetal Alchemist: Brotherhood   9.09
# 3                                     Gintama Season 4   9.06
# 6                                      Hunter x Hunter   9.04
# 7                                     Gintama Season 2   9.03
# ..                                                 ...    ...
# 954        Welcome to Demon School! Iruma-kun Season 3   7.82
# 964                             Dusk Maiden of Amnesia   7.82
# 974                                   Bungo Stray Dogs   7.81
# 975                                Fire Force Season 2   7.81
# 981  The 100 Girlfriends Who Really, Really, Really...   7.81
#
#                              Rating  \
# 0         PG-13 - Teens 13 or older
# 1    R - 17+ (violence & profanity)
# 3         PG-13 - Teens 13 or older
# 6         PG-13 - Teens 13 or older
# ...

# %%
distinctSource = df['Source'].unique()
distinctSource
# Out:
# array(['Manga', 'Web manga', 'Light novel', '4-koma manga', 'Novel'],
#       dtype=object)

# %%
distinctStudios = df['Studios'].unique()
distinctStudios
# Out:
# array(['Madhouse', 'Bones', 'Bandai Namco Pictures', 'Sunrise', 'Pierrot',
#        'A-1 Pictures', 'TMS Entertainment', 'Shin-Ei Animation', 'MAPPA',
#        'Tokyo Movie Shinsha', 'Artland', 'Toei Animation', 'Doga Kobo',
#        "Brain's Base", 'Shuka', 'Tatsunoko Production', 'OLM',
#        'David Production', 'Wit Studio', 'J.C.Staff', 'Production I.G',
#        'HAL Film Maker', 'Lerche', 'ufotable', 'J.C.Staff, Egg Firm',
#        'Nippon Animation', 'Orange', '8bit', 'Gallop, Studio Comet',
#        'Mushi Production', 'Tezuka Productions, MAPPA',
#        'Gallop, Studio Deen', 'Geno Studio', 'Studio Deen',
#        'Telecom Animation Film', 'Science SARU', 'feel.', 'CloverWorks',
#        'C2C', 'Trigger', 'Drive', 'Gallop', 'Bibury Animation Studios',
#        'Manglobe', 'E&G Films', 'MAPPA, Studio VOLN',
#        'Hoods Entertainment', 'Madhouse, TMS Entertainment',
#        'Tezuka Productions', 'Seven Arcs', 'BUG FILMS', 'SILVER LINK.'],
#       dtype=object)

# %%
distinctRatings = df['Rating'].unique()
distinctRatings
# Out:
# array(['PG-13 - Teens 13 or older', 'R - 17+ (violence & profanity)',
#        'R+ - Mild Nudity', 'G - All Ages', 'PG - Children'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162 entries, 0 to 981
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   English  162 non-null    object
#  1   Score    162 non-null    float64
#  2   Rating   162 non-null    object
#  3   Genres   162 non-null    object
#  4   Studios  162 non-null    object
#  5   Source   162 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 8.9+ KB

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   English  162 non-null    object
#  1   Score    162 non-null    float64
#  2   Rating   162 non-null    object
#  3   Genres   162 non-null    object
#  4   Studios  162 non-null    object
#  5   Source   162 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 7.7+ KB

# %%
df.head(30)
# Out:
#                                              English  Score  \
# 0                      Frieren: Beyond Journey's End   9.38
# 1                   Fullmetal Alchemist: Brotherhood   9.09
# 2                                   Gintama Season 4   9.06
# 3                                    Hunter x Hunter   9.04
# 4                                   Gintama Season 2   9.03
# 5                    Bleach: Thousand-Year Blood War   9.02
# 6                                 Gintama: Enchousen   9.02
# 7          Kaguya-sama: Love is War - Ultra Romantic   9.01
# 8                    Fruits Basket: The Final Season   8.98
# 9                                   Gintama Season 5   8.98
# 10                                           Gintama   8.94
# 11                  The Dangers in My Heart Season 2   8.89
# 12       Gintama.: Silver Soul Arc - Second Half War   8.88
# 13                           Jujutsu Kaisen Season 2   8.84
# 14                     Attack on Titan: Final Season   8.79
# ...

# %%
rating_mapping = {
    'PG-13 - Teens 13 or older': 'PG-13',
    'R - 17+ (violence & profanity)': 'R-17+',
    'R+ - Mild Nudity': 'R+',
    'G - All Ages': 'G',
    'PG - Children': 'PG'
}

df.loc[:, 'Rating'] = df['Rating'].replace(rating_mapping)

# %%
df = df.rename(columns={"English": "Title"})
df
# Out:
#                                                  Title  Score Rating  \
# 0                        Frieren: Beyond Journey's End   9.38  PG-13
# 1                     Fullmetal Alchemist: Brotherhood   9.09  R-17+
# 2                                     Gintama Season 4   9.06  PG-13
# 3                                      Hunter x Hunter   9.04  PG-13
# 4                                     Gintama Season 2   9.03  PG-13
# ..                                                 ...    ...    ...
# 157        Welcome to Demon School! Iruma-kun Season 3   7.82  PG-13
# 158                             Dusk Maiden of Amnesia   7.82  R-17+
# 159                                   Bungo Stray Dogs   7.81  R-17+
# 160                                Fire Force Season 2   7.81  PG-13
# 161  The 100 Girlfriends Who Really, Really, Really...   7.81  PG-13
#
#                                                 Genres  \
# 0       AdventureAdventure, DramaDrama, FantasyFantasy
# ...

# %%
df.head(30)
# Out:
#                                                Title  Score Rating  \
# 0                      Frieren: Beyond Journey's End   9.38  PG-13
# 1                   Fullmetal Alchemist: Brotherhood   9.09  R-17+
# 2                                   Gintama Season 4   9.06  PG-13
# 3                                    Hunter x Hunter   9.04  PG-13
# 4                                   Gintama Season 2   9.03  PG-13
# 5                    Bleach: Thousand-Year Blood War   9.02  R-17+
# 6                                 Gintama: Enchousen   9.02  PG-13
# 7          Kaguya-sama: Love is War - Ultra Romantic   9.01  PG-13
# 8                    Fruits Basket: The Final Season   8.98  PG-13
# 9                                   Gintama Season 5   8.98  PG-13
# 10                                           Gintama   8.94  PG-13
# 11                  The Dangers in My Heart Season 2   8.89  PG-13
# 12       Gintama.: Silver Soul Arc - Second Half War   8.88  PG-13
# ...

# %%
df.to_csv('AnimeList.csv')
